# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files_dir = 'nfl-draft-data/'

profiles_file = 'nfl_draft_profiles.csv'
prospects_file = 'nfl_draft_prospects.csv'
stats_file = 'college_statistics.csv'

profiles_path = files_dir + profiles_file
prospects_path = files_dir + prospects_file
stats_path = files_dir + stats_file

# %%
profiles_df = pd.read_csv(profiles_path)
prospects_df = pd.read_csv(prospects_path)
stats_df = pd.read_csv(stats_path)

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Prospects

# %%
prospects_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   draft_year      13354 non-null  int64
#  1   player_id       13354 non-null  int64
#  2   player_name     13354 non-null  object
#  3   position        13045 non-null  object
#  4   pos_abbr        13045 non-null  object
#  5   school          13145 non-null  object
#  6   school_name     13127 non-null  object
#  7   school_abbr     12958 non-null  object
#  8   link            13354 non-null  object
#  9   pick            11788 non-null  float64
#  10  overall         11788 non-null  float64
#  11  round           11788 non-null  float64
#  12  traded          11788 non-null  object
#  13  trade_note      4506 non-null   object
#  14  team            11788 non-null  object
#  15  team_abbr       11788 non-null  object
#  16  team_logo_espn  11754 non-null  object
#  17  guid            6172 non-null   object
#  18  weight          6112 non-null   float64
#  19  height          6081 non-null   float64
#  20  pos_rk          5989 non-null   float64
#  21  ovr_rk          5220 non-null   float64
#  22  grade           5995 non-null   float64
#  23  player_image    1531 non-null   object
# dtypes: float64(8), int64(2), object(14)
# memory usage: 2.4+ MB

# %%
prospects_df.describe()
# Out:
#          draft_year      player_id          pick       overall         round  \
# count  13354.000000   13354.000000  11788.000000  11788.000000  11788.000000
# mean    1998.189831   29884.278718     16.905921    113.918392      4.110875
# std       16.116808   28600.931243     10.123831     67.882416      2.004959
# min     1967.000000       1.000000      1.000000      1.000000      1.000000
# 25%     1984.000000   13684.250000      8.000000     56.000000      2.000000
# 50%     2001.000000   20725.500000     16.000000    112.000000      4.000000
# 75%     2012.000000   28963.750000     24.000000    167.000000      6.000000
# max     2021.000000  105496.000000     54.000000    262.000000      7.000000
#
#             weight       height       pos_rk       ovr_rk        grade
# count  6112.000000  6081.000000  5989.000000  5220.000000  5995.000000
# mean    244.736093    73.941169    15.862581   156.325670    57.787490
# std      86.888394     2.684655    14.069466    96.825064    20.367434
# min     155.000000    38.000000     1.000000     1.000000    20.000000
# 25%     205.000000    72.000000     6.000000    73.000000    39.000000
# 50%     234.000000    74.000000    13.000000   148.000000    57.000000
# 75%     285.000000    76.000000    22.000000   235.000000    74.000000
# max    6022.000000    81.625000   151.000000   373.000000    99.000000

# %% [markdown]
# ## Profiles

# %%
profiles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12905 entries, 0 to 12904
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player_id      12905 non-null  int64
#  1   guid           5949 non-null   object
#  2   alt_player_id  5882 non-null   float64
#  3   player_name    12905 non-null  object
#  4   position       12905 non-null  object
#  5   pos_abbr       12905 non-null  object
#  6   weight         12905 non-null  int64
#  7   height         12905 non-null  float64
#  8   player_image   1506 non-null   object
#  9   link           12905 non-null  object
#  10  school_logo    12485 non-null  object
#  11  school         12905 non-null  object
#  12  school_abbr    12867 non-null  object
#  13  school_name    12895 non-null  object
#  14  pos_rk         5761 non-null   float64
#  15  ovr_rk         5100 non-null   float64
#  16  grade          5767 non-null   float64
#  17  text1          2992 non-null   object
#  18  text2          3848 non-null   object
#  19  text3          534 non-null    object
#  20  text4          2 non-null      object
# dtypes: float64(5), int64(2), object(14)
# memory usage: 2.1+ MB

# %%
profiles_df.describe()
# Out:
#            player_id  alt_player_id        weight        height       pos_rk  \
# count   12905.000000   5.882000e+03  12905.000000  12905.000000  5761.000000
# mean    30054.561875   2.715410e+06    124.214878     33.460672    15.453394
# std     28767.447874   7.808098e+05    136.383997     36.825631    13.460563
# min         1.000000   1.302900e+04      0.000000      0.000000     1.000000
# 25%     13980.000000   2.158407e+06      0.000000      0.000000     6.000000
# 50%     20691.000000   2.470314e+06    178.000000      0.000000    13.000000
# 75%     29007.000000   3.084650e+06    235.000000     73.625000    21.000000
# max    105496.000000   4.820589e+06   6022.000000     81.625000   151.000000
#
#             ovr_rk        grade
# count  5100.000000  5767.000000
# mean    155.609608    58.343333
# std      97.114488    20.321728
# min       1.000000    20.000000
# 25%      72.000000    40.000000
# 50%     147.000000    58.000000
# 75%     234.250000    75.000000
# max     373.000000    99.000000

# %% [markdown]
# # Removing cols

# %%
cols_remove_prospects = ['draft_year','position','school_name','school_abbr', 'link', 'round', 'trade_note', 'team', 'team_logo_espn', 'guid', 'player_image']
cols_prospects = list(prospects_df.columns)

for i in cols_remove_prospects:
    cols_prospects.remove(i)
print(cols_prospects)

df_prospects = prospects_df[cols_prospects].copy()

df_prospects
# Out:
# ['player_id', 'player_name', 'pos_abbr', 'school', 'pick', 'overall', 'traded', 'team_abbr', 'weight', 'height', 'pos_rk', 'ovr_rk', 'grade']
#        player_id        player_name pos_abbr              school  pick  \
# 0          23590        Bubba Smith       DE      Michigan State   1.0
# 1          23591      Clinton Jones       RB      Michigan State   2.0
# 2          23592     Steve Spurrier       QB             Florida   3.0
# 3          23593         Bob Griese       QB              Purdue   4.0
# 4          23594     George Webster       LB      Michigan State   5.0
# ...          ...                ...      ...                 ...   ...
# 13349     105466        Justus Reed       DE       Virginia Tech   NaN
# 13350     105467      K.J. Costello       QB   Mississippi State   NaN
# 13351     105468     Donovan Stiner        S             Florida   NaN
# 13352     105478     Mac McCain III       CB  North Carolina A&T   NaN
# 13353     105479  Josh Imatorbhebhe       WR            Illinois   NaN
#
#        overall traded team_abbr  weight  height  pos_rk  ovr_rk  grade
# 0          1.0  False       IND     NaN     NaN     NaN     NaN    NaN
# 1          2.0  False       MIN     NaN     NaN     NaN     NaN    NaN
# 2          3.0  False        SF     NaN     NaN     NaN     NaN    NaN
# 3          4.0  False       MIA     NaN     NaN     NaN     NaN    NaN
# 4          5.0  False       TEN     NaN     NaN     NaN     NaN    NaN
# ...        ...    ...       ...     ...     ...     ...     ...    ...
# 13349      NaN    NaN       NaN   253.0  75.000    31.0   344.0   30.0
# 13350      NaN    NaN       NaN   227.0  76.625    15.0   345.0   30.0
# 13351      NaN    NaN       NaN   205.0  73.500    29.0   346.0   30.0
# 13352      NaN    NaN       NaN   186.0  71.000    44.0   348.0   30.0
# 13353      NaN    NaN       NaN   218.0  72.875    54.0   349.0   30.0
#
# [13354 rows x 13 columns]

# %%
df_clear = df_prospects.dropna().copy()
df_clear
# Out:
#        player_id          player_name pos_abbr                school  pick  \
# 7202        7841          Eli Manning       QB              Ole Miss   1.0
# 7203        7747       Robert Gallery       OT                  Iowa   2.0
# 7204        7993     Larry Fitzgerald       WR            Pittsburgh   3.0
# 7205        7842        Philip Rivers       QB  North Carolina State   4.0
# 7206        7405          Sean Taylor       DB                 Miami   5.0
# ...          ...                  ...      ...                   ...   ...
# 13241     105459  Pressley Harvin III        P          Georgia Tech  27.0
# 13243     104931           Kylin Hill       RB     Mississippi State  29.0
# 13244     105325     Jermar Jefferson       RB          Oregon State  30.0
# 13245     105318            Dax Milne       WR                   BYU  31.0
# 13246     105194         Grant Stuard      OLB               Houston  32.0
#
#        overall traded team_abbr  weight  height  pos_rk  ovr_rk  grade
# 7202       1.0  False        SD   221.0    77.0     2.0     5.0   98.0
# 7203       2.0  False       OAK   323.0    79.0     1.0     2.0   99.0
# 7204       3.0  False       ARI   221.0    75.0     1.0     1.0   99.0
# 7205       4.0  False       NYG   224.0    77.0     3.0    14.0   95.0
# 7206       5.0  False       WSH   228.0    75.0     1.0     3.0   99.0
# ...        ...    ...       ...     ...     ...     ...     ...    ...
# 13241    254.0   True       PIT   263.0    71.0     4.0   337.0   30.0
# 13243    256.0  False        GB   214.0    71.0    16.0   219.0   44.0
# 13244    257.0   True       DET   206.0    70.0    10.0   163.0   59.0
# 13245    258.0   True       WSH   193.0    73.0    44.0   279.0   34.0
# 13246    259.0  False        TB   225.0    72.0     9.0   216.0   45.0
#
# [3598 rows x 13 columns]

# %%
df_clear['team_abbr'].value_counts()
# Out:
# MIN    136
# BAL    132
# CIN    131
# CLE    130
# SF     127
# GB     121
# TEN    120
# PHI    119
# DAL    116
# DEN    116
# BUF    112
# TB     111
# NE     110
# SEA    109
# IND    109
# PIT    109
# DET    109
# ARI    109
# MIA    108
# CAR    108
# HOU    107
# NYJ    106
# JAX    106
# WSH    106
# KC     106
# NYG    106
# ATL    102
# CHI     98
# OAK     96
# NO      90
# STL     76
# SD      68
# LAR     42
# LAC     34
# LV      13
# Name: team_abbr, dtype: int64

# %% [markdown]
# Teams that changed cities since 2004
#
# STL -> LAR
#
# SD -> LAC
#
# OAK -> LV

# %%
df_clear.replace(to_replace = 'STL', value = 'LAR', inplace=True)
df_clear.replace(to_replace = 'SD', value = 'LAC', inplace=True)
df_clear.replace(to_replace = 'OAK', value = 'LV', inplace=True)

# %%
df_clear['team_abbr'].value_counts()
# Out:
# MIN    136
# BAL    132
# CIN    131
# CLE    130
# SF     127
# GB     121
# TEN    120
# PHI    119
# LAR    118
# DAL    116
# DEN    116
# BUF    112
# TB     111
# NE     110
# SEA    109
# IND    109
# PIT    109
# LV     109
# ARI    109
# DET    109
# MIA    108
# CAR    108
# HOU    107
# WSH    106
# NYG    106
# KC     106
# NYJ    106
# JAX    106
# ATL    102
# LAC    102
# CHI     98
# NO      90
# Name: team_abbr, dtype: int64

# %%
features = list(df_clear.columns)
features.remove('team_abbr')

# %% [markdown]
# # Creating network

# %%
path_save = "nfl.net.gz"
path_graph = "nfl_graph.net.gz"

# %%
import netpixi
from netpixi.integration.gt import *
from regression.integration.gt import *
# Out:
#     <script src="/files/netpixi.min.js"></script>
# <frozen importlib._bootstrap>:914: ImportWarning: VendorImporter.find_spec() not found; falling back to find_module()

# %%
cols = list(df_clear.columns)
team_abbr_index = cols.index("team_abbr")
player_id_index = cols.index("player_id")

# %%
g = Graph(directed=False)

# %%
for i in features:
    g.add_vp(i)

# %%
for i in df_clear.values:
    g.add_vertex(i[player_id_index])
    try:
        g.add_vertex(i[team_abbr_index])
    except:
        pass
    g.add_edge(i[player_id_index], i[team_abbr_index])

# %%
gt_save(g, path_save)

# %%
g = gt_load(path_save)
m = gt_draw.sfdp_layout(g)
gt_move(g, m)
gt_save(g, path_graph)

# %%
r = netpixi.render(path_graph)
# Out:
#         <div id="VMBGXdBPnD5TsusqbDag67"></div>
#         <script>netpixi.render('VMBGXdBPnD5TsusqbDag67', 'nfl_graph.net.gz', 1.7777777777777777, true, false, false);</script>

# %%
# mudar a cor de fundo do grafo
r.graph(color = 0x000002, kscale = 2)

# mudar a cor e o tamanho dos vértices
r.vertex_default(color = 0x03FF07, size = 4)

# configurando arestas
r.edge_default(color = 0x48FA22, width = 0.3, curve1 = 1, curve2 = 2)
# Out:
#         <div id="mEHvTAoWpTpexZ3wa9hVmt"></div>
#         <script>netpixi.call('mEHvTAoWpTpexZ3wa9hVmt', 'VMBGXdBPnD5TsusqbDag67', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJncmFwaCI6IHsiY29sb3IiOiAyLCAia3NjYWxlIjogMn19fQo=');</script>
#         <div id="i4LRerpqhCGwEfAxAsmo2B"></div>
#         <script>netpixi.call('i4LRerpqhCGwEfAxAsmo2B', 'VMBGXdBPnD5TsusqbDag67', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJ2ZXJ0ZXgiOiB7ImNvbG9yIjogMjYxODk1LCAic2l6ZSI6IDR9fX0K');</script>
#         <div id="FEBpG6yKhabJhz4KzGebtr"></div>
#         <script>netpixi.call('FEBpG6yKhabJhz4KzGebtr', 'VMBGXdBPnD5TsusqbDag67', 'changeGraph', 'eyJ0eXBlIjogInNldHRpbmdzIiwgInByb3BzIjogeyJlZGdlIjogeyJjb2xvciI6IDQ3ODI2MjYsICJ3aWR0aCI6IDAuMywgImN1cnZlMSI6IDEsICJjdXJ2ZTIiOiAyfX19Cg==');</script>
