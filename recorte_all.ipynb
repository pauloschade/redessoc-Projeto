# %%
import numpy as np
import pandas as pd
import math
import regression as reg
from model import Model, data_dir, file_save_name
# Out:
#     <script src="/files/netpixi.min.js"></script>

# %%
rec = pd.read_csv(data_dir + file_save_name + "_" + str(2017) + "_" + str(2020) + ".csv")
rec
# Out:
#     Unnamed: 0    id  betweenness  clustering  parlamentares   success  gender
# 0            0   155     0.000073    0.981818       0.147059  0.588235       1
# 1            1   160     0.002306    0.858974       0.147059  0.555556       1
# 2            2   187     0.003156    0.904348       0.191176  0.940845       1
# 3            3   220     0.005550    0.875116       0.058824  0.924188       1
# 4            4   224     0.002885    0.914141       0.191176  0.915942       1
# ..         ...   ...          ...         ...            ...       ...     ...
# 63          63  2174     0.052702    0.560440       0.029412  0.717949       1
# 64          64  2180     0.000000    1.000000       0.147059  0.333333       1
# 65          65  2185     0.051025    0.772727       0.058824  0.532787       1
# 66          66  2186     0.003584    0.915854       0.191176  0.982143       1
# 67          67  2203     0.000000    0.000000       0.029412  0.166667       1
#
# [68 rows x 7 columns]

# %%
reg_clu = reg.linear(data=rec, formula='clustering ~ parlamentares + gender')
reg_bet__rep = reg.linear(data=rec, formula='betweenness ~ parlamentares')
reg_clu__ep = reg.linear(data=rec, formula='clustering ~ extreme_party + gender')
reg_clu__rep_ep = reg.linear(data=rec, formula='clustering ~ parlamentares + extreme_party + gender')
display(reg_clu__rep.micro_summary())
display(reg_bet__rep.micro_summary())
display(reg_clu__ep.micro_summary())
display(reg_clu__rep_ep.micro_summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/patsy/compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/patsy/eval.py:165, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     164 code = compile(expr, source_name, "eval", self.flags, False)
# --> 165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'extreme_party' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In [6], line 3
# ...
